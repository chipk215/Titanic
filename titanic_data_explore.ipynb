# %% [markdown]
# # Titanic Data Set Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_df = pd.read_csv('data/train.csv')
print("Describe: ")
print(titanic_df.describe() )
print()
print("Head: ")
print(titanic_df.head() )
print()
print("Info: ")
print(titanic_df.info())
# titanic_df
# Out:
# Describe:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#
# Head:
#    PassengerId  Survived  Pclass  \
# ...

# %%
titanic_df.shape[0]
info =
# Out:
# 891

# %%
 pd.set_option("display.max_rows",550)
titanic_df.sort_values(by="Name")
titanic_df[titanic_df['Survived']==0][['Name','Age','Pclass']].sort_values(by="Pclass")
# Out:
#                                                   Name   Age  Pclass
# 536                  Butt, Major. Archibald Willingham  45.0       1
# 177                         Isham, Miss. Ann Elizabeth  50.0       1
# 766                          Brewe, Dr. Arthur Jackson   NaN       1
# 174                            Smith, Mr. James Clinch  56.0       1
# 659                         Newell, Mr. Arthur Webster  58.0       1
# 170                          Van der hoef, Mr. Wyckoff  61.0       1
# 452                    Foreman, Mr. Benjamin Laventall  30.0       1
# 168                                Baumann, Mr. John D   NaN       1
# 456                          Millet, Mr. Francis Davis  65.0       1
# 602                          Harrington, Mr. Charles H   NaN       1
# 462                                  Gee, Mr. Arthur H  47.0       1
# 782                             Long, Mr. Milton Clyde  29.0       1
# 438                                  Fortune, Mr. Mark  64.0       1
# ...

# %% [markdown]
# ### How representative is this sample of the data wrt to survival?

# %%
titanic_df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
342/891.0
# Out:
# 0.3838383838383838

# %% [markdown]
# #### EDA
#
# For each variable:
# * Is it categorical?
# * If so, What are the categories?
# * Min, Max, Mean for quantitatives
# * Missing values?
# * Something about the distribution of the variable.

# %%
titanic_df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic_df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# #### Female Data

# %%
titanic_df[titanic_data_frame.Sex== 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %% [markdown]
# #### Check for missing sex values

# %%
titanic_df[titanic_df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Examine Fare

# %%
titanic_df.Fare.plot(kind="hist", bins=10)

# %%
titanic_df[titanic_df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic_df[titanic_df.Fare == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
#women and children first
fig, axs = plt.subplots(1,2)
titanic_df[titanic_df.Sex=='male'].Survived.value_counts().plot(kind='barh', ax=axs[0], title="Male Survivorship")
titanic_df[titanic_df.Sex=='female'].Survived.value_counts().plot(kind='barh', ax=axs[1], title="Female Survivorship")

# %%
titanic_df[titanic_df.Age < 15].Survived.value_counts().plot(kind='barh')

# %%
titanic_df[(titanic_df.Age < 15) & (titanic_df.Sex =='female')].Survived.value_counts().plot(kind='barh', title="Girl Survivorship")

# %%
titanic_df[(titanic_df.Age < 15) & (titanic_df.Sex =='male')].Survived.value_counts().plot(kind='barh', title="Boy Survivorship")

# %% [markdown]
# ##### Pclass survivorship

# %%
titanic_df[(titanic_df.Pclass == 1)].Survived.value_counts().plot(kind='barh', title="First Class Survivorship")

# %%
titanic_df[(titanic_df.Pclass == 2)].Survived.value_counts().plot(kind='barh', title="Second Class Survivorship")

# %%
titanic_df[(titanic_df.Pclass == 3)].Survived.value_counts().plot(kind='barh', title="Third Class Survivorship")

# %%
titanic_df[((titanic_df.Pclass == 1) & (titanic_df.Sex == 'female'))].Survived.value_counts().plot(kind='barh', title="First Class Female Survivorship")
titanic_df[((titanic_df.Pclass == 1) & (titanic_df.Sex == 'female') & (titanic_df.Survived == 0))]
# Out:
#      PassengerId  Survived  Pclass  \
# 177          178         0       1
# 297          298         0       1
# 498          499         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 297                     Allison, Miss. Helen Loraine  female   2.0      1
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
#
#      Parch    Ticket      Fare    Cabin Embarked
# 177      0  PC 17595   28.7125      C49        C
# 297      2    113781  151.5500  C22 C26        S
# 498      2    113781  151.5500  C22 C26        S

# %%
titanic_df[((titanic_df.Pclass == 1) & (titanic_df.Sex == 'male'))].Survived.value_counts().plot(kind='barh', title="First Class Male Survivorship")
