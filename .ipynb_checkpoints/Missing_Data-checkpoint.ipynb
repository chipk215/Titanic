# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# #### Summary Feature Analysis
#
# |Feature   |    Type            |   Missing Data   |    Missing Count   |  Odd Values |
# |    ---   |    ---             |    ---           |     ---            | ---         |
# |Survived  |Numeric- int64      |No                |                    |             |
# |Pclass    |Numeric- int64      |No                |                    |             |
# |Name      |Object- text        |No                |                    |             |
# |Sex       |Object- categorical |No                |                    |             |
# |Age       |Numeric- float64    |Yes               |177                 |             |
# |SibSp     |Numeric- int64      |No                |                    |             |
# |Parch     |Numeric- int64      |No                |                    |             |
# |Ticket    |Object- categorical |No                |                    |             |
# |Fare      | Numeric- float64   |No                |                    |Min val = 0  |
# |Cabin     |Object- categorical |Yes               |687                 |             |
# |Embarked  |Object- categorical |Yes               | 2                  |             |

# %% [markdown]
# #### First Model
# * Use average of age for missing age values
# * Use numeric features {Pclass, Age, SibSp, Parch, Fare}
# * Use categorical features {Sex,Ticket}
# * Algorithm: Random Forest Classifier

# %%
df = pd.read_csv('data/train.csv')
# Random Forrest error predictions
df[df['PassengerId'].isin([56,114,268,299,313,484,502,504,506,655,713,741,840])]
# Out:
#      PassengerId  Survived  Pclass  \
# 55            56         1       1
# 113          114         0       3
# 267          268         1       3
# 298          299         1       1
# 312          313         0       2
# 483          484         1       3
# 501          502         0       3
# 503          504         0       3
# 505          506         0       1
# 654          655         0       3
# 712          713         1       1
# 740          741         1       1
# 839          840         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 55                            Woolner, Mr. Hugh    male   NaN      0      0
# 113                     Jussila, Miss. Katriina  female  20.0      1      0
# 267                    Persson, Mr. Ernst Ulrik    male  25.0      1      0
# 298                       Saalfeld, Mr. Adolphe    male   NaN      0      0
# 312       Lahtinen, Mrs. William (Anna Sylfven)  female  26.0      1      1
# ...

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# ### Handling missing age...
#
# Strategies
# * Drop observation with missing age
# * Set Nan to 0 in continuous or create new category if categorical  (not a good option for age)
# * Use the mean
# * Create an ml algorithm to predict the missing value  (perhaps using linear regression)

# %% [markdown]
# #### Subset

# %%
# drops rows if where Age or Cabin has an Nan value
df.dropna(subset=['Age','Cabin'], how='any').shape
# Out:
# (185, 12)

# %%
# df['Fare']

# %% [markdown]
# #### Look at test data

# %%
df_test = pd.read_csv('data/test.csv')
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# #### Embarked

# %%
# input data again
df = pd.read_csv('data/train.csv')

# %%
# print unique values for embark
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# determine indices of passengers with nan embarkment
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df[df['Fare']<100]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
first_class_S = df[((df['Embarked']=='S') & (df['Pclass']==1))]['Embarked'].count()
first_class_S
# Out:
# 127

# %%
second_class_S = df[((df['Embarked']=='S') & (df['Pclass']==2))]['Embarked'].count()
second_class_S
# Out:
# 164

# %%
third_class_S = df[((df['Embarked']=='S') & (df['Pclass']==3))]['Embarked'].count()
third_class_S
# Out:
# 353

# %%
first_class_C = df[((df['Embarked']=='C') & (df['Pclass']==1))]['Embarked'].count()
first_class_C
# Out:
# 85

# %%
second_class_C = df[((df['Embarked']=='C') & (df['Pclass']==2))]['Embarked'].count()
second_class_C
# Out:
# 17

# %%
third_class_C = df[((df['Embarked']=='C') & (df['Pclass']==3))]['Embarked'].count()
third_class_C
# Out:
# 66

# %%
first_class_Q = df[((df['Embarked']=='Q') & (df['Pclass']==1))]['Embarked'].count()
first_class_Q
# Out:
# 2

# %%
sns.countplot(data=df, x= 'Pclass', hue='Embarked')

# %%
sns.countplot(data=df, x= 'Embarked', hue='Pclass')
